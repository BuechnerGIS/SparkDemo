# %%
# Install dependencies for pulling OSM data
# !pip install leafmap geopandas osmnx shapely
import leafmap
import osmnx
import geopandas
import shapely
# Out:
# Requirement already satisfied: leafmap in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (0.38.6)
# Requirement already satisfied: geopandas in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (0.14.4)
# Requirement already satisfied: osmnx in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (1.9.4)
# Requirement already satisfied: shapely in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (2.0.6)
# Requirement already satisfied: anywidget>=0.9.13 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from leafmap) (0.9.13)
# Requirement already satisfied: bqplot>=0.12.43 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from leafmap) (0.12.43)
# Requirement already satisfied: colour>=0.1.5 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from leafmap) (0.1.5)
# Requirement already satisfied: folium>=0.14.0 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from leafmap) (0.17.0)
# Requirement already satisfied: gdown>=5.1.0 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from leafmap) (5.2.0)
# Requirement already satisfied: geojson>=3.1.0 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from leafmap) (3.1.0)
# Requirement already satisfied: ipyevents>=2.0.2 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from leafmap) (2.0.2)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from leafmap) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.18.2 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from leafmap) (0.19.2)
# Requirement already satisfied: ipyvuetify>=1.9.4 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from leafmap) (1.10.0)
# Requirement already satisfied: ipywidgets>=7.6.0 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from leafmap) (8.1.5)
# Requirement already satisfied: matplotlib>=3.7.1 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from leafmap) (3.9.2)
# Requirement already satisfied: numpy<3.0.0,>=1.25.0 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from leafmap) (1.26.4)
# Requirement already satisfied: pandas>=2.0.3 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from leafmap) (2.2.3)
# Requirement already satisfied: plotly>=5.15.0 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from leafmap) (5.24.1)
# Requirement already satisfied: psutil>=5.9.5 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from leafmap) (6.0.0)
# Requirement already satisfied: pyshp>=2.3.1 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from leafmap) (2.3.1)
# Requirement already satisfied: pystac-client>=0.8.2 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from leafmap) (0.8.4)
# Requirement already satisfied: python-box>=7.2.0 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from leafmap) (7.2.0)
# Requirement already satisfied: scooby>=0.10.0 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from leafmap) (0.10.0)
# Requirement already satisfied: setuptools>=70.0.0 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from leafmap) (75.2.0)
# Requirement already satisfied: whiteboxgui>=2.3.0 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from leafmap) (2.3.0)
# Requirement already satisfied: xyzservices>=2024.6.0 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from leafmap) (2024.9.0)
# Requirement already satisfied: duckdb>=0.10.3 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from leafmap) (1.1.2)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from geopandas) (1.10.1)
# Requirement already satisfied: packaging in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from geopandas) (24.1)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from geopandas) (3.7.0)
# Requirement already satisfied: networkx<3.4,>=2.5 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from osmnx) (3.3)
# Requirement already satisfied: requests<2.33,>=2.27 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from osmnx) (2.32.3)
# Requirement already satisfied: psygnal>=0.8.1 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from anywidget>=0.9.13->leafmap) (0.11.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from anywidget>=0.9.13->leafmap) (4.12.2)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from bqplot>=0.12.43->leafmap) (5.14.3)
# Requirement already satisfied: traittypes>=0.0.6 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from bqplot>=0.12.43->leafmap) (0.2.1)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from fiona>=1.8.21->geopandas) (24.2.0)
# Requirement already satisfied: certifi in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from fiona>=1.8.21->geopandas) (2024.8.30)
# Requirement already satisfied: click~=8.0 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from fiona>=1.8.21->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: branca>=0.6.0 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from folium>=0.14.0->leafmap) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from folium>=0.14.0->leafmap) (3.1.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from gdown>=5.1.0->leafmap) (4.12.3)
# Requirement already satisfied: filelock in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from gdown>=5.1.0->leafmap) (3.16.1)
# Requirement already satisfied: tqdm in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from gdown>=5.1.0->leafmap) (4.66.5)
# Requirement already satisfied: jupyter-leaflet<0.20,>=0.19 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from ipyleaflet>=0.18.2->leafmap) (0.19.2)
# Requirement already satisfied: ipyvue<2,>=1.7 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from ipyvuetify>=1.9.4->leafmap) (1.11.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from ipywidgets>=7.6.0->leafmap) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from ipywidgets>=7.6.0->leafmap) (8.28.0)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from ipywidgets>=7.6.0->leafmap) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from ipywidgets>=7.6.0->leafmap) (3.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from matplotlib>=3.7.1->leafmap) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from matplotlib>=3.7.1->leafmap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from matplotlib>=3.7.1->leafmap) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from matplotlib>=3.7.1->leafmap) (1.4.7)
# Requirement already satisfied: pillow>=8 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from matplotlib>=3.7.1->leafmap) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from matplotlib>=3.7.1->leafmap) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from matplotlib>=3.7.1->leafmap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from pandas>=2.0.3->leafmap) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from pandas>=2.0.3->leafmap) (2024.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from plotly>=5.15.0->leafmap) (9.0.0)
# Requirement already satisfied: pystac>=1.10.0 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from pystac[validation]>=1.10.0->pystac-client>=0.8.2->leafmap) (1.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from requests<2.33,>=2.27->osmnx) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from requests<2.33,>=2.27->osmnx) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from requests<2.33,>=2.27->osmnx) (2.2.3)
# Requirement already satisfied: ipytree in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from whiteboxgui>=2.3.0->leafmap) (0.2.2)
# Requirement already satisfied: whitebox in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from whiteboxgui>=2.3.0->leafmap) (2.3.5)
# Requirement already satisfied: colorama in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas) (0.4.6)
# Requirement already satisfied: decorator in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->leafmap) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->leafmap) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->leafmap) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->leafmap) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->leafmap) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->leafmap) (0.6.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from jinja2>=2.9->folium>=0.14.0->leafmap) (3.0.1)
# Requirement already satisfied: jsonschema~=4.18 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from pystac[validation]>=1.10.0->pystac-client>=0.8.2->leafmap) (4.23.0)
# Requirement already satisfied: six>=1.5 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.7.1->leafmap) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from beautifulsoup4->gdown>=5.1.0->leafmap) (2.6)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from requests[socks]->gdown>=5.1.0->leafmap) (1.7.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.6.0->leafmap) (0.8.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client>=0.8.2->leafmap) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client>=0.8.2->leafmap) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client>=0.8.2->leafmap) (0.20.0)
# Requirement already satisfied: wcwidth in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.6.0->leafmap) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.6.0->leafmap) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.6.0->leafmap) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\chr14058\projects\sparkdemo\venv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.6.0->leafmap) (0.2.3)

# %%
# Create a map over Parkway West
m = leafmap.Map(center=[38.622800689786146, -90.53972968259362], zoom=15)
m
# Out:
# Map(center=[38.622800689786146, -90.53972968259362], controls=(ZoomControl(options=['position', 'zoom_in_text'…

# %%
# Let's add some satellite imagery!
m = leafmap.Map(center=[38.622800689786146, -90.53972968259362], zoom=15)
m.add_tile_layer(
    url="https://mt1.google.com/vt/lyrs=y&x={x}&y={y}&z={z}",
    name="Google Satellite",
    attribution="Google",
)
m
# Out:
# Map(center=[38.622800689786146, -90.53972968259362], controls=(ZoomControl(options=['position', 'zoom_in_text'…

# %%
# Chris is running errands at home depot and gets hungry.. Let's make a new map and find some restaraunts!
area_map = leafmap.Map(center=[38.506100126287556, -90.32222702087451], zoom=17)
area_map
# Out:
# Map(center=[38.506100126287556, -90.32222702087451], controls=(ZoomControl(options=['position', 'zoom_in_text'…

# %%
north, south, east, west = 38.478454,38.531247,-90.361691,-90.279980
tags={"building": ["yes", "house", "amenity"],
      "house": "yes"}

gdf = osmnx.geometries_from_bbox(north, south, east, west, tags)
(gdf)
# Out:
#                                                                   geometry  \
# element_type osmid
# way          102923920   POLYGON ((-90.33982 38.51041, -90.33982 38.510...
#              152170243   POLYGON ((-90.32023 38.47909, -90.32023 38.478...
#              152173100   POLYGON ((-90.32038 38.48888, -90.32087 38.488...
#              152225072   POLYGON ((-90.30341 38.47912, -90.30361 38.479...
#              152238669   POLYGON ((-90.33293 38.48207, -90.33321 38.482...
# ...                                                                    ...
#              1280943148  POLYGON ((-90.33575 38.48974, -90.33557 38.489...
#              1280943149  POLYGON ((-90.33569 38.48945, -90.33562 38.489...
#              1280943150  POLYGON ((-90.33568 38.48937, -90.33559 38.489...
#              1282498249  POLYGON ((-90.29927 38.49857, -90.29923 38.498...
#              1301396981  POLYGON ((-90.33787 38.50792, -90.33788 38.507...
#
#                         addr:housenumber addr:postcode     addr:street  \
# element_type osmid
# way          102923920              4140         63128      Rusty Road
#              152170243               NaN           NaN             NaN
#              152173100                 2         63129   Nazareth Lane
#              152225072              4556         63129  Telegraph Road
#              152238669               NaN           NaN             NaN
# ...                                  ...           ...             ...
#              1280943148              NaN           NaN             NaN
#              1280943149              NaN           NaN             NaN
#              1280943150              NaN           NaN             NaN
#              1282498249             3150         63125  Telegraph Road
#              1301396981              NaN           NaN             NaN
#
#                         note:post_town  \
# element_type osmid
# way          102923920     Saint Louis
#              152170243             NaN
#              152173100     Saint Louis
#              152225072             NaN
#              152238669             NaN
# ...                                ...
#              1280943148            NaN
#              1280943149            NaN
#              1280943150            NaN
#              1282498249            NaN
#              1301396981            NaN
#
#                                                                      nodes  \
# element_type osmid
# way          102923920   [1188496851, 1188500748, 6871757431, 687175743...
#              152170243   [1649984672, 3201006789, 3201006791, 320100679...
#              152173100   [1650022565, 1650022605, 1650022607, 165002258...
#              152225072   [1650583385, 1650583404, 1650583416, 165058340...
#              152238669   [1650665496, 1650665467, 1650665508, 165066549...
# ...                                                                    ...
#              1280943148  [11889601489, 11889601490, 11889601491, 118896...
#              1280943149  [11889601494, 11889601495, 11889601496, 118896...
#              1280943150  [11889601498, 11889601499, 11889601500, 118896...
#              1282498249  [11901407597, 11901407598, 11901407599, 119014...
#              1301396981  [12054081695, 12054081692, 12054081693, 120540...
#
#                            addr:city addr:state           amenity     brand  \
# element_type osmid
# way          102923920   Saint Louis         MO         fast_food  Culver's
#              152170243           NaN        NaN            school       NaN
#              152173100           NaN        NaN      nursing_home       NaN
#              152225072   Saint Louis        NaN  place_of_worship       NaN
#              152238669           NaN        NaN            school       NaN
# ...                              ...        ...               ...       ...
#              1280943148          NaN        NaN               NaN       NaN
#              1280943149          NaN        NaN               NaN       NaN
#              1280943150          NaN        NaN               NaN       NaN
#              1282498249  Saint Louis         MO         fast_food   Popeyes
#              1301396981          NaN        NaN               NaN       NaN
#
#                          ... contact:facebook contact:instagram email sport  \
# element_type osmid       ...
# way          102923920   ...              NaN               NaN   NaN   NaN
#              152170243   ...              NaN               NaN   NaN   NaN
#              152173100   ...              NaN               NaN   NaN   NaN
#              152225072   ...              NaN               NaN   NaN   NaN
#              152238669   ...              NaN               NaN   NaN   NaN
# ...                      ...              ...               ...   ...   ...
#              1280943148  ...              NaN               NaN   NaN   NaN
#              1280943149  ...              NaN               NaN   NaN   NaN
#              1280943150  ...              NaN               NaN   NaN   NaN
#              1282498249  ...              NaN               NaN   NaN   NaN
#              1301396981  ...              NaN               NaN   NaN   NaN
#
#                         level:ref roof:shape craft addr:country museum house
# element_type osmid
# way          102923920        NaN        NaN   NaN          NaN    NaN   NaN
#              152170243        NaN        NaN   NaN          NaN    NaN   NaN
#              152173100        NaN        NaN   NaN          NaN    NaN   NaN
#              152225072        NaN        NaN   NaN          NaN    NaN   NaN
#              152238669        NaN        NaN   NaN          NaN    NaN   NaN
# ...                           ...        ...   ...          ...    ...   ...
#              1280943148       NaN        NaN   NaN          NaN    NaN   NaN
#              1280943149       NaN        NaN   NaN          NaN    NaN   NaN
#              1280943150       NaN        NaN   NaN          NaN    NaN   NaN
#              1282498249       NaN        NaN   NaN          NaN    NaN   NaN
#              1301396981       NaN        NaN   NaN          NaN    NaN   NaN
#
# [4360 rows x 106 columns]

# %%
# Convert the projection system from geographic to projected
gdf = gdf.to_crs(epsg=3395)  
gdf
# Out:
#                                                                   geometry  \
# element_type osmid
# way          102923920   POLYGON ((-10056582.995 4625173.235, -10056582...
#              152170243   POLYGON ((-10054401.723 4620737.758, -10054402...
#              152173100   POLYGON ((-10054418.910 4622123.277, -10054473...
#              152225072   POLYGON ((-10052530.097 4620741.950, -10052551...
#              152238669   POLYGON ((-10055815.792 4621159.045, -10055846...
# ...                                                                    ...
#              1280943148  POLYGON ((-10056129.679 4622245.339, -10056109...
#              1280943149  POLYGON ((-10056122.789 4622204.789, -10056115...
#              1280943150  POLYGON ((-10056121.720 4622193.288, -10056111...
#              1282498249  POLYGON ((-10052068.444 4623495.954, -10052064...
#              1301396981  POLYGON ((-10056365.888 4624820.478, -10056366...
#
#                         addr:housenumber addr:postcode     addr:street  \
# element_type osmid
# way          102923920              4140         63128      Rusty Road
#              152170243               NaN           NaN             NaN
#              152173100                 2         63129   Nazareth Lane
#              152225072              4556         63129  Telegraph Road
#              152238669               NaN           NaN             NaN
# ...                                  ...           ...             ...
#              1280943148              NaN           NaN             NaN
#              1280943149              NaN           NaN             NaN
#              1280943150              NaN           NaN             NaN
#              1282498249             3150         63125  Telegraph Road
#              1301396981              NaN           NaN             NaN
#
#                         note:post_town  \
# element_type osmid
# way          102923920     Saint Louis
#              152170243             NaN
#              152173100     Saint Louis
#              152225072             NaN
#              152238669             NaN
# ...                                ...
#              1280943148            NaN
#              1280943149            NaN
#              1280943150            NaN
#              1282498249            NaN
#              1301396981            NaN
#
#                                                                      nodes  \
# element_type osmid
# way          102923920   [1188496851, 1188500748, 6871757431, 687175743...
#              152170243   [1649984672, 3201006789, 3201006791, 320100679...
#              152173100   [1650022565, 1650022605, 1650022607, 165002258...
#              152225072   [1650583385, 1650583404, 1650583416, 165058340...
#              152238669   [1650665496, 1650665467, 1650665508, 165066549...
# ...                                                                    ...
#              1280943148  [11889601489, 11889601490, 11889601491, 118896...
#              1280943149  [11889601494, 11889601495, 11889601496, 118896...
#              1280943150  [11889601498, 11889601499, 11889601500, 118896...
#              1282498249  [11901407597, 11901407598, 11901407599, 119014...
#              1301396981  [12054081695, 12054081692, 12054081693, 120540...
#
#                            addr:city addr:state           amenity     brand  \
# element_type osmid
# way          102923920   Saint Louis         MO         fast_food  Culver's
#              152170243           NaN        NaN            school       NaN
#              152173100           NaN        NaN      nursing_home       NaN
#              152225072   Saint Louis        NaN  place_of_worship       NaN
#              152238669           NaN        NaN            school       NaN
# ...                              ...        ...               ...       ...
#              1280943148          NaN        NaN               NaN       NaN
#              1280943149          NaN        NaN               NaN       NaN
#              1280943150          NaN        NaN               NaN       NaN
#              1282498249  Saint Louis         MO         fast_food   Popeyes
#              1301396981          NaN        NaN               NaN       NaN
#
#                          ... contact:facebook contact:instagram email sport  \
# element_type osmid       ...
# way          102923920   ...              NaN               NaN   NaN   NaN
#              152170243   ...              NaN               NaN   NaN   NaN
#              152173100   ...              NaN               NaN   NaN   NaN
#              152225072   ...              NaN               NaN   NaN   NaN
#              152238669   ...              NaN               NaN   NaN   NaN
# ...                      ...              ...               ...   ...   ...
#              1280943148  ...              NaN               NaN   NaN   NaN
#              1280943149  ...              NaN               NaN   NaN   NaN
#              1280943150  ...              NaN               NaN   NaN   NaN
#              1282498249  ...              NaN               NaN   NaN   NaN
#              1301396981  ...              NaN               NaN   NaN   NaN
#
#                         level:ref roof:shape craft addr:country museum house
# element_type osmid
# way          102923920        NaN        NaN   NaN          NaN    NaN   NaN
#              152170243        NaN        NaN   NaN          NaN    NaN   NaN
#              152173100        NaN        NaN   NaN          NaN    NaN   NaN
#              152225072        NaN        NaN   NaN          NaN    NaN   NaN
#              152238669        NaN        NaN   NaN          NaN    NaN   NaN
# ...                           ...        ...   ...          ...    ...   ...
#              1280943148       NaN        NaN   NaN          NaN    NaN   NaN
#              1280943149       NaN        NaN   NaN          NaN    NaN   NaN
#              1280943150       NaN        NaN   NaN          NaN    NaN   NaN
#              1282498249       NaN        NaN   NaN          NaN    NaN   NaN
#              1301396981       NaN        NaN   NaN          NaN    NaN   NaN
#
# [4360 rows x 106 columns]

# %%
# Add all buildings which met query criteria above to map
area_map.add_gdf(gdf, layer_name="Buildings", fill_colors=["green"])
area_map
# Ignore the error for now
# Out:
# C:\Users\chr14058\Projects\SparkDemo\venv\Lib\site-packages\leafmap\leafmap.py:2658: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   geom_type = gdf.geom_type[0]
# Map(bottom=12883136.0, center=[38.506100126287556, -90.32222702087451], controls=(ZoomControl(options=['positi…

# %%
# Trim data frames to only contain two columns
small_gdf = gdf[["name", "addr:street", "amenity", "geometry"]]

# Make a new dataframe of only restaraunts
restaraunts = small_gdf.query("amenity in ['restaraunt', 'fast_food']")
restaraunts
# Out:
#                                      name                addr:street  \
# element_type osmid
# way          102923920           Culver's                 Rusty Road
#              515705315          Taco Bell           Butler Hill Road
#              515705323       White Castle           Lemay Ferry Road
#              515705387        Burger King           Butler Hill Road
#              515725260          Taco Bell           Lemay Ferry Road
#              578817354           Hardee's           Butler Hill Road
#              578817359            Popeyes    First Missouri CU Drive
#              607758268      Lion's Choice                        NaN
#              641390401         McDonald's  South Lindbergh Boulevard
#              705820934     Steak 'n Shake                        NaN
#              751439647   Church's Chicken  South Lindbergh Boulevard
#              914868278      Smoothie King                        NaN
#              914868287        Chick-fil-A           Lemay Ferry Road
#              914868293                KFC                 Union Road
#              914868297            Wendy's  South Lindbergh Boulevard
#              914877547         McDonald's           Lemay Ferry Road
#              916503970           Hardee's           Lemay Ferry Road
#              923976836     Steak 'n Shake                        NaN
#              923976842          Taco Bell             Telegraph Road
#              940566500    Jack in the Box           Lemay Ferry Road
#              1056732503      White Castle                        NaN
#              1066549172     Panda Express  South Lindbergh Boulevard
#              1066549185  DQ Grill & Chill  South Lindbergh Boulevard
#              1086560791      Krispy Kreme                        NaN
#              1282498249           Popeyes             Telegraph Road
#
#                            amenity  \
# element_type osmid
# way          102923920   fast_food
#              515705315   fast_food
#              515705323   fast_food
#              515705387   fast_food
#              515725260   fast_food
#              578817354   fast_food
#              578817359   fast_food
#              607758268   fast_food
#              641390401   fast_food
#              705820934   fast_food
#              751439647   fast_food
#              914868278   fast_food
#              914868287   fast_food
#              914868293   fast_food
#              914868297   fast_food
#              914877547   fast_food
#              916503970   fast_food
#              923976836   fast_food
#              923976842   fast_food
#              940566500   fast_food
#              1056732503  fast_food
#              1066549172  fast_food
#              1066549185  fast_food
#              1086560791  fast_food
#              1282498249  fast_food
#
#                                                                   geometry
# element_type osmid
# way          102923920   POLYGON ((-10056582.995 4625173.235, -10056582...
#              515705315   POLYGON ((-10058506.016 4621620.061, -10058515...
#              515705323   POLYGON ((-10055767.735 4623965.053, -10055776...
#              515705387   POLYGON ((-10058576.660 4621626.477, -10058577...
#              515725260   POLYGON ((-10054726.174 4624978.175, -10054735...
#              578817354   POLYGON ((-10058658.101 4621754.099, -10058652...
#              578817359   POLYGON ((-10057933.823 4621627.142, -10057915...
#              607758268   POLYGON ((-10056928.319 4626543.634, -10056914...
#              641390401   POLYGON ((-10057337.529 4626798.138, -10057323...
#              705820934   POLYGON ((-10055314.008 4624646.619, -10055296...
#              751439647   POLYGON ((-10057898.680 4627049.575, -10057883...
#              914868278   POLYGON ((-10054847.780 4624474.010, -10054840...
#              914868287   POLYGON ((-10055288.828 4624376.344, -10055289...
#              914868293   POLYGON ((-10055858.605 4624907.352, -10055866...
#              914868297   POLYGON ((-10055898.435 4625232.782, -10055913...
#              914877547   POLYGON ((-10055859.718 4623848.296, -10055863...
#              916503970   POLYGON ((-10052638.400 4626530.201, -10052618...
#              923976836   POLYGON ((-10051979.499 4623185.085, -10051979...
#              923976842   POLYGON ((-10052095.049 4623358.083, -10052123...
#              940566500   POLYGON ((-10056035.659 4623545.392, -10056031...
#              1056732503  POLYGON ((-10058210.931 4626988.259, -10058206...
#              1066549172  POLYGON ((-10056820.350 4625843.619, -10056824...
#              1066549185  POLYGON ((-10056894.979 4626431.609, -10056898...
#              1086560791  POLYGON ((-10055805.806 4625193.028, -10055791...
#              1282498249  POLYGON ((-10052068.444 4623495.954, -10052064...

# %%
# Convert to points
restaraunts['geometry'] = restaraunts['geometry'].centroid
restaraunts
# Out:
# C:\Users\chr14058\Projects\SparkDemo\venv\Lib\site-packages\geopandas\geodataframe.py:1528: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#                                      name                addr:street  \
# element_type osmid
# way          102923920           Culver's                 Rusty Road
#              515705315          Taco Bell           Butler Hill Road
#              515705323       White Castle           Lemay Ferry Road
#              515705387        Burger King           Butler Hill Road
#              515725260          Taco Bell           Lemay Ferry Road
#              578817354           Hardee's           Butler Hill Road
#              578817359            Popeyes    First Missouri CU Drive
#              607758268      Lion's Choice                        NaN
#              641390401         McDonald's  South Lindbergh Boulevard
#              705820934     Steak 'n Shake                        NaN
#              751439647   Church's Chicken  South Lindbergh Boulevard
#              914868278      Smoothie King                        NaN
#              914868287        Chick-fil-A           Lemay Ferry Road
#              914868293                KFC                 Union Road
#              914868297            Wendy's  South Lindbergh Boulevard
#              914877547         McDonald's           Lemay Ferry Road
#              916503970           Hardee's           Lemay Ferry Road
#              923976836     Steak 'n Shake                        NaN
#              923976842          Taco Bell             Telegraph Road
#              940566500    Jack in the Box           Lemay Ferry Road
#              1056732503      White Castle                        NaN
#              1066549172     Panda Express  South Lindbergh Boulevard
#              1066549185  DQ Grill & Chill  South Lindbergh Boulevard
#              1086560791      Krispy Kreme                        NaN
#              1282498249           Popeyes             Telegraph Road
#
#                            amenity                           geometry
# element_type osmid
# way          102923920   fast_food  POINT (-10056561.062 4625181.878)
#              515705315   fast_food  POINT (-10058503.419 4621606.995)
#              515705323   fast_food  POINT (-10055761.269 4623951.495)
#              515705387   fast_food  POINT (-10058568.912 4621611.471)
#              515725260   fast_food  POINT (-10054720.351 4624964.320)
#              578817354   fast_food  POINT (-10058648.443 4621741.206)
#              578817359   fast_food  POINT (-10057919.389 4621619.351)
#              607758268   fast_food  POINT (-10056928.016 4626528.251)
#              641390401   fast_food  POINT (-10057315.460 4626817.728)
#              705820934   fast_food  POINT (-10055294.957 4624652.754)
#              751439647   fast_food  POINT (-10057893.455 4627039.649)
#              914868278   fast_food  POINT (-10054852.644 4624471.519)
#              914868287   fast_food  POINT (-10055299.036 4624371.326)
#              914868293   fast_food  POINT (-10055876.638 4624909.539)
#              914868297   fast_food  POINT (-10055908.956 4625227.096)
#              914877547   fast_food  POINT (-10055874.884 4623832.007)
#              916503970   fast_food  POINT (-10052634.979 4626513.685)
#              923976836   fast_food  POINT (-10051996.189 4623176.055)
#              923976842   fast_food  POINT (-10052112.539 4623355.790)
#              940566500   fast_food  POINT (-10056046.639 4623543.488)
#              1056732503  fast_food  POINT (-10058205.934 4626976.254)
#              1066549172  fast_food  POINT (-10056835.095 4625848.045)
#              1066549185  fast_food  POINT (-10056882.594 4626421.215)
#              1086560791  fast_food  POINT (-10055807.990 4625172.882)
#              1282498249  fast_food  POINT (-10052080.749 4623507.594)

# %%
# Add it to the map!
area_map.add_gdf(restaraunts, layer_name="Restaraunts", fill_colors=["green"])
area_map
# Out:
# C:\Users\chr14058\Projects\SparkDemo\venv\Lib\site-packages\leafmap\leafmap.py:2658: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   geom_type = gdf.geom_type[0]
# Map(bottom=805521.0, center=[38.50022087618732, -90.34323692321779], controls=(ZoomControl(options=['position'…

# %%
# Create a data frame of just Home Depot
home_depot = small_gdf[gdf['name'] == 'The Home Depot']
home_depot
# Out:
#                                   name               addr:street amenity  \
# element_type osmid
# way          914868276  The Home Depot  South Lindberg Boulevard     NaN
#
#                                                                  geometry
# element_type osmid
# way          914868276  POLYGON ((-10054517.639 4624559.478, -10054531...

# %%
# Buffer the Home Depot by 1-mile (~1600m)
home_depot_centroid = home_depot['geometry']
home_depot['geometry'] = home_depot['geometry'].buffer(1600)
# Ignore the warning for now...
# Out:
# C:\Users\chr14058\Projects\SparkDemo\venv\Lib\site-packages\geopandas\geodataframe.py:1528: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# Add that buffer to the map!
area_map.add_gdf(home_depot, layer_name="Home Depot Buffer", fill_colors=["red"])
area_map
# Out:
# C:\Users\chr14058\Projects\SparkDemo\venv\Lib\site-packages\leafmap\leafmap.py:2658: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   geom_type = gdf.geom_type[0]
# Map(bottom=805521.0, center=[38.50022087618732, -90.34323692321779], controls=(ZoomControl(options=['position'…

# %%
restaraunts = restaraunts.reset_index(drop=True)
home_depot = home_depot.reset_index(drop=True)

# %%
# Spatial join
restaurants_within_range = geopandas.sjoin(restaraunts, home_depot, how="inner", op="within")

# Convert to centroids
restaurants_within_range['geometry'] = restaurants_within_range['geometry'].centroid

# Drop columns from the right join Walmart table
columns_to_drop = [col for col in restaurants_within_range.columns if col.endswith("_right")]
restaurants_within_range = restaurants_within_range.drop(columns=columns_to_drop)

# Display the result
restaurants_within_range
# Out:
# C:\Users\chr14058\Projects\SparkDemo\venv\Lib\site-packages\IPython\core\interactiveshell.py:3517: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#          name_left           addr:street_left amenity_left  \
# 2     White Castle           Lemay Ferry Road    fast_food
# 4        Taco Bell           Lemay Ferry Road    fast_food
# 9   Steak 'n Shake                        NaN    fast_food
# 11   Smoothie King                        NaN    fast_food
# 12     Chick-fil-A           Lemay Ferry Road    fast_food
# 13             KFC                 Union Road    fast_food
# 14         Wendy's  South Lindbergh Boulevard    fast_food
# 15      McDonald's           Lemay Ferry Road    fast_food
# 23    Krispy Kreme                        NaN    fast_food
#
#                              geometry
# 2   POINT (-10055761.269 4623951.495)
# 4   POINT (-10054720.351 4624964.320)
# 9   POINT (-10055294.957 4624652.754)
# 11  POINT (-10054852.644 4624471.519)
# 12  POINT (-10055299.036 4624371.326)
# 13  POINT (-10055876.638 4624909.539)
# 14  POINT (-10055908.956 4625227.096)
# 15  POINT (-10055874.884 4623832.007)
# 23  POINT (-10055807.990 4625172.882)

# %%
# Add the restaraunts within 1-mile to the map!
area_map.add_gdf(restaurants_within_range, layer_name="Restaraunt Choices", fill_colors=["green"])
area_map
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Projects\SparkDemo\venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Add the restaraunts within 1-mile to the map!
# ----> 2 area_map.add_gdf(restaurants_within_range, layer_name="Restaraunt Choices", fill_colors=["green"])
#       3 area_map
#
# File ~\Projects\SparkDemo\venv\Lib\site-packages\leafmap\leafmap.py:2882, in Map.add_gdf(self, gdf, layer_name, style, hover_style, style_callback, fill_colors, info_mode, zoom_to_layer, encoding, **kwargs)
#    2879     except:
#    2880         pass
# -> 2882 self.add_geojson(
#    2883     gdf,
#    2884     layer_name,
#    2885     style,
#    2886     hover_style,
#    2887     style_callback,
#    2888     fill_colors,
#    2889     info_mode,
#    2890     zoom_to_layer,
#    2891     encoding,
#    2892     **kwargs,
#    2893 )
#
# File ~\Projects\SparkDemo\venv\Lib\site-packages\leafmap\leafmap.py:2658, in Map.add_geojson(self, in_geojson, layer_name, style, hover_style, style_callback, fill_colors, info_mode, zoom_to_layer, encoding, **kwargs)
#    2655     gdf = gdf.to_crs("EPSG:4326")
#    2656 data = gdf.__geo_interface__
# -> 2658 geom_type = gdf.geom_type[0]
#    2660 if style is None and (style_callback is None):
#    2661     style = {
#    2662         # "stroke": True,
#    2663         "color": "#3388ff",
#    (...)
#    2670         # "clickable": True,
#    2671     }
#
# File ~\Projects\SparkDemo\venv\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File ~\Projects\SparkDemo\venv\Lib\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File ~\Projects\SparkDemo\venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 0
